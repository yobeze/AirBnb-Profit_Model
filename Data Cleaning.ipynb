# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.graphics.gofplots import qqplot_2samples
import seaborn as sns


df = pd.read_csv("listings.csv")

# %%
#We're dropping the nan's in "Bathrooms_text" column
df = df.dropna(axis = 0, subset = ['bathrooms_text'])
df = df.dropna(axis = 0, subset = ['beds'])

# %%
#Creating new lists to replace the "bathroom_text"
baths = []
private = []
for i in  df["bathrooms_text"]:
    split = i.split()
    if split[0] == "Shared" or "Half-bath":
        baths.append(1)
    else:
        baths.append(float(split[0]))
    if "shared" in split:
        private.append("shared")
    elif "private" in split:
        private.append("private")
    else:
        private.append("private")

# %%
#We are adding the new rows
df["n_bathrooms"] = baths
df["shared_private"] = private

# %%
# Fill blank spaces in bedrooms with a 1
df["bedrooms"].fillna(value = 1, inplace = True)
df["reviews_per_month"].fillna(value = 0, inplace = True)

# %%
df["price"]
pricev2 = []
for i in df["price"]:
    j = i.split("$")
    aux = j[1].replace(",","")
    pricev2.append(float(aux))
#print(pricev2)
df["price"] = pricev2

# %%
df.corr()
# Out:
#                                                     id  scrape_id   host_id  \
# id                                            1.000000        NaN  0.442450
# scrape_id                                          NaN        NaN       NaN
# host_id                                       0.442450        NaN  1.000000
# host_listings_count                           0.161028        NaN  0.106619
# host_total_listings_count                     0.161028        NaN  0.106619
# neighbourhood_group_cleansed                       NaN        NaN       NaN
# latitude                                     -0.019168        NaN -0.050892
# longitude                                     0.000464        NaN  0.082023
# accommodates                                  0.000556        NaN -0.009343
# bathrooms                                          NaN        NaN       NaN
# bedrooms                                     -0.018807        NaN -0.043333
# beds                                          0.000398        NaN  0.014963
# price                                         0.052151        NaN  0.046937
# minimum_nights                               -0.031758        NaN  0.004684
# maximum_nights                               -0.031767        NaN -0.042104
# minimum_minimum_nights                       -0.031933        NaN  0.004138
# maximum_minimum_nights                        0.086324        NaN -0.005580
# minimum_maximum_nights                       -0.005706        NaN -0.111000
# maximum_maximum_nights                        0.019013        NaN -0.062861
# minimum_nights_avg_ntm                        0.084436        NaN -0.005141
# maximum_nights_avg_ntm                        0.011269        NaN -0.081867
# calendar_updated                                   NaN        NaN       NaN
# availability_30                               0.177456        NaN  0.250809
# availability_60                               0.203942        NaN  0.269772
# availability_90                               0.202826        NaN  0.263674
# availability_365                              0.074604        NaN  0.200987
# number_of_reviews                            -0.513992        NaN -0.209808
# number_of_reviews_ltm                        -0.134183        NaN -0.048604
# number_of_reviews_l30d                       -0.014453        NaN -0.020760
# review_scores_rating                         -0.039588        NaN -0.069943
# review_scores_accuracy                       -0.058971        NaN -0.098569
# review_scores_cleanliness                    -0.025499        NaN -0.051341
# review_scores_checkin                        -0.045510        NaN -0.076964
# review_scores_communication                  -0.070121        NaN -0.102497
# review_scores_location                       -0.013089        NaN -0.034447
# review_scores_value                          -0.128419        NaN -0.130533
# calculated_host_listings_count                0.220619        NaN  0.329966
# calculated_host_listings_count_entire_homes   0.205071        NaN  0.288948
# calculated_host_listings_count_private_rooms  0.084815        NaN  0.193700
# calculated_host_listings_count_shared_rooms   0.016022        NaN  0.005926
# reviews_per_month                            -0.056624        NaN -0.035374
# n_bathrooms                                        NaN        NaN       NaN
#
#                                               host_listings_count  \
# id                                                       0.161028
# scrape_id                                                     NaN
# host_id                                                  0.106619
# host_listings_count                                      1.000000
# host_total_listings_count                                1.000000
# neighbourhood_group_cleansed                                  NaN
# latitude                                                -0.016016
# longitude                                               -0.001202
# accommodates                                            -0.046837
# bathrooms                                                     NaN
# bedrooms                                                -0.043558
# beds                                                    -0.050128
# price                                                   -0.000430
# minimum_nights                                           0.076366
# maximum_nights                                           0.073875
# minimum_minimum_nights                                   0.080192
# maximum_minimum_nights                                   0.729101
# minimum_maximum_nights                                  -0.014524
# maximum_maximum_nights                                  -0.022296
# minimum_nights_avg_ntm                                   0.726143
# maximum_nights_avg_ntm                                  -0.020294
# calendar_updated                                              NaN
# availability_30                                          0.186986
# availability_60                                          0.195070
# availability_90                                          0.182983
# availability_365                                         0.203113
# number_of_reviews                                       -0.106812
# number_of_reviews_ltm                                   -0.113778
# number_of_reviews_l30d                                  -0.114268
# review_scores_rating                                    -0.095595
# review_scores_accuracy                                  -0.085376
# review_scores_cleanliness                               -0.038670
# review_scores_checkin                                   -0.015749
# review_scores_communication                             -0.130195
# review_scores_location                                  -0.027203
# review_scores_value                                     -0.113838
# calculated_host_listings_count                           0.527686
# calculated_host_listings_count_entire_homes              0.532582
# calculated_host_listings_count_private_rooms            -0.008726
# calculated_host_listings_count_shared_rooms             -0.005942
# reviews_per_month                                       -0.062149
# n_bathrooms                                                   NaN
#
#                                               host_total_listings_count  \
# id                                                             0.161028
# scrape_id                                                           NaN
# host_id                                                        0.106619
# host_listings_count                                            1.000000
# host_total_listings_count                                      1.000000
# neighbourhood_group_cleansed                                        NaN
# latitude                                                      -0.016016
# longitude                                                     -0.001202
# accommodates                                                  -0.046837
# bathrooms                                                           NaN
# bedrooms                                                      -0.043558
# beds                                                          -0.050128
# price                                                         -0.000430
# minimum_nights                                                 0.076366
# maximum_nights                                                 0.073875
# minimum_minimum_nights                                         0.080192
# maximum_minimum_nights                                         0.729101
# minimum_maximum_nights                                        -0.014524
# maximum_maximum_nights                                        -0.022296
# minimum_nights_avg_ntm                                         0.726143
# maximum_nights_avg_ntm                                        -0.020294
# calendar_updated                                                    NaN
# availability_30                                                0.186986
# availability_60                                                0.195070
# availability_90                                                0.182983
# availability_365                                               0.203113
# number_of_reviews                                             -0.106812
# number_of_reviews_ltm                                         -0.113778
# number_of_reviews_l30d                                        -0.114268
# review_scores_rating                                          -0.095595
# review_scores_accuracy                                        -0.085376
# review_scores_cleanliness                                     -0.038670
# review_scores_checkin                                         -0.015749
# review_scores_communication                                   -0.130195
# review_scores_location                                        -0.027203
# review_scores_value                                           -0.113838
# calculated_host_listings_count                                 0.527686
# calculated_host_listings_count_entire_homes                    0.532582
# calculated_host_listings_count_private_rooms                  -0.008726
# calculated_host_listings_count_shared_rooms                   -0.005942
# reviews_per_month                                             -0.062149
# n_bathrooms                                                         NaN
#
#                                               neighbourhood_group_cleansed  \
# id                                                                     NaN
# scrape_id                                                              NaN
# host_id                                                                NaN
# host_listings_count                                                    NaN
# host_total_listings_count                                              NaN
# neighbourhood_group_cleansed                                           NaN
# latitude                                                               NaN
# longitude                                                              NaN
# accommodates                                                           NaN
# bathrooms                                                              NaN
# bedrooms                                                               NaN
# beds                                                                   NaN
# price                                                                  NaN
# minimum_nights                                                         NaN
# maximum_nights                                                         NaN
# minimum_minimum_nights                                                 NaN
# maximum_minimum_nights                                                 NaN
# minimum_maximum_nights                                                 NaN
# maximum_maximum_nights                                                 NaN
# minimum_nights_avg_ntm                                                 NaN
# maximum_nights_avg_ntm                                                 NaN
# calendar_updated                                                       NaN
# availability_30                                                        NaN
# availability_60                                                        NaN
# availability_90                                                        NaN
# availability_365                                                       NaN
# number_of_reviews                                                      NaN
# number_of_reviews_ltm                                                  NaN
# number_of_reviews_l30d                                                 NaN
# review_scores_rating                                                   NaN
# review_scores_accuracy                                                 NaN
# review_scores_cleanliness                                              NaN
# review_scores_checkin                                                  NaN
# review_scores_communication                                            NaN
# review_scores_location                                                 NaN
# review_scores_value                                                    NaN
# calculated_host_listings_count                                         NaN
# calculated_host_listings_count_entire_homes                            NaN
# calculated_host_listings_count_private_rooms                           NaN
# calculated_host_listings_count_shared_rooms                            NaN
# reviews_per_month                                                      NaN
# n_bathrooms                                                            NaN
#
#                                               latitude  longitude  \
# id                                           -0.019168   0.000464
# scrape_id                                          NaN        NaN
# host_id                                      -0.050892   0.082023
# host_listings_count                          -0.016016  -0.001202
# host_total_listings_count                    -0.016016  -0.001202
# neighbourhood_group_cleansed                       NaN        NaN
# latitude                                      1.000000   0.047983
# longitude                                     0.047983   1.000000
# accommodates                                  0.067705  -0.042948
# bathrooms                                          NaN        NaN
# bedrooms                                      0.028954  -0.011425
# beds                                          0.044414  -0.022486
# price                                         0.033916  -0.085027
# minimum_nights                               -0.043169   0.062368
# maximum_nights                                0.040104   0.006214
# minimum_minimum_nights                       -0.045322   0.064918
# maximum_minimum_nights                       -0.015243  -0.001401
# minimum_maximum_nights                        0.037042   0.035339
# maximum_maximum_nights                        0.054824   0.014818
# minimum_nights_avg_ntm                       -0.015801  -0.000361
# maximum_nights_avg_ntm                        0.051191   0.020712
# calendar_updated                                   NaN        NaN
# availability_30                              -0.038248   0.083786
# availability_60                              -0.034718   0.095932
# availability_90                              -0.038542   0.086223
# availability_365                             -0.044152   0.054603
# number_of_reviews                             0.074247   0.007700
# number_of_reviews_ltm                         0.071114  -0.015082
# number_of_reviews_l30d                        0.074632  -0.032640
# review_scores_rating                          0.017418  -0.071868
# review_scores_accuracy                        0.004911  -0.074057
# review_scores_cleanliness                     0.021821  -0.062018
# review_scores_checkin                         0.010182  -0.088805
# review_scores_communication                  -0.007208  -0.062469
# review_scores_location                       -0.007334  -0.083962
# review_scores_value                          -0.004088  -0.018999
# calculated_host_listings_count               -0.015141  -0.040251
# calculated_host_listings_count_entire_homes  -0.019821  -0.064962
# calculated_host_listings_count_private_rooms  0.019621   0.109585
# calculated_host_listings_count_shared_rooms  -0.024676   0.054503
# reviews_per_month                             0.043984  -0.011035
# n_bathrooms                                        NaN        NaN
#
#                                               accommodates  bathrooms  ...  \
# id                                                0.000556        NaN  ...
# scrape_id                                              NaN        NaN  ...
# host_id                                          -0.009343        NaN  ...
# host_listings_count                              -0.046837        NaN  ...
# host_total_listings_count                        -0.046837        NaN  ...
# neighbourhood_group_cleansed                           NaN        NaN  ...
# latitude                                          0.067705        NaN  ...
# longitude                                        -0.042948        NaN  ...
# accommodates                                      1.000000        NaN  ...
# bathrooms                                              NaN        NaN  ...
# bedrooms                                          0.820730        NaN  ...
# beds                                              0.723596        NaN  ...
# price                                             0.492479        NaN  ...
# minimum_nights                                   -0.113203        NaN  ...
# maximum_nights                                    0.033066        NaN  ...
# minimum_minimum_nights                           -0.113499        NaN  ...
# maximum_minimum_nights                           -0.094639        NaN  ...
# minimum_maximum_nights                            0.038539        NaN  ...
# maximum_maximum_nights                            0.055871        NaN  ...
# minimum_nights_avg_ntm                           -0.096654        NaN  ...
# maximum_nights_avg_ntm                            0.052090        NaN  ...
# calendar_updated                                       NaN        NaN  ...
# availability_30                                   0.047578        NaN  ...
# availability_60                                   0.044101        NaN  ...
# availability_90                                   0.035844        NaN  ...
# availability_365                                  0.034043        NaN  ...
# number_of_reviews                                -0.021921        NaN  ...
# number_of_reviews_ltm                             0.026146        NaN  ...
# number_of_reviews_l30d                            0.005471        NaN  ...
# review_scores_rating                              0.022617        NaN  ...
# review_scores_accuracy                           -0.006143        NaN  ...
# review_scores_cleanliness                        -0.009362        NaN  ...
# review_scores_checkin                             0.015817        NaN  ...
# review_scores_communication                      -0.011078        NaN  ...
# review_scores_location                           -0.050368        NaN  ...
# review_scores_value                              -0.019174        NaN  ...
# calculated_host_listings_count                   -0.085145        NaN  ...
# calculated_host_listings_count_entire_homes      -0.055678        NaN  ...
# calculated_host_listings_count_private_rooms     -0.131232        NaN  ...
# calculated_host_listings_count_shared_rooms      -0.073552        NaN  ...
# reviews_per_month                                 0.042544        NaN  ...
# n_bathrooms                                            NaN        NaN  ...
#
#                                               review_scores_checkin  \
# id                                                        -0.045510
# scrape_id                                                       NaN
# host_id                                                   -0.076964
# host_listings_count                                       -0.015749
# host_total_listings_count                                 -0.015749
# neighbourhood_group_cleansed                                    NaN
# latitude                                                   0.010182
# longitude                                                 -0.088805
# accommodates                                               0.015817
# bathrooms                                                       NaN
# bedrooms                                                   0.014050
# beds                                                      -0.007936
# price                                                     -0.001274
# minimum_nights                                            -0.038949
# maximum_nights                                            -0.032242
# minimum_minimum_nights                                    -0.039056
# maximum_minimum_nights                                    -0.016235
# minimum_maximum_nights                                     0.005471
# maximum_maximum_nights                                     0.000604
# minimum_nights_avg_ntm                                    -0.016421
# maximum_nights_avg_ntm                                     0.004099
# calendar_updated                                                NaN
# availability_30                                           -0.095473
# availability_60                                           -0.100595
# availability_90                                           -0.094374
# availability_365                                          -0.090682
# number_of_reviews                                          0.068821
# number_of_reviews_ltm                                      0.067462
# number_of_reviews_l30d                                     0.071415
# review_scores_rating                                       0.584908
# review_scores_accuracy                                     0.563823
# review_scores_cleanliness                                  0.495817
# review_scores_checkin                                      1.000000
# review_scores_communication                                0.585550
# review_scores_location                                     0.465646
# review_scores_value                                        0.489377
# calculated_host_listings_count                            -0.076798
# calculated_host_listings_count_entire_homes               -0.063549
# calculated_host_listings_count_private_rooms              -0.027195
# calculated_host_listings_count_shared_rooms               -0.111490
# reviews_per_month                                          0.025479
# n_bathrooms                                                     NaN
#
#                                               review_scores_communication  \
# id                                                              -0.070121
# scrape_id                                                             NaN
# host_id                                                         -0.102497
# host_listings_count                                             -0.130195
# host_total_listings_count                                       -0.130195
# neighbourhood_group_cleansed                                          NaN
# latitude                                                        -0.007208
# longitude                                                       -0.062469
# accommodates                                                    -0.011078
# bathrooms                                                             NaN
# bedrooms                                                        -0.020371
# beds                                                            -0.031433
# price                                                           -0.008948
# minimum_nights                                                  -0.026951
# maximum_nights                                                  -0.050569
# minimum_minimum_nights                                          -0.025884
# maximum_minimum_nights                                          -0.086700
# minimum_maximum_nights                                           0.013636
# maximum_maximum_nights                                           0.011100
# minimum_nights_avg_ntm                                          -0.085801
# maximum_nights_avg_ntm                                           0.014764
# calendar_updated                                                      NaN
# availability_30                                                 -0.084658
# availability_60                                                 -0.088463
# availability_90                                                 -0.088010
# availability_365                                                -0.081552
# number_of_reviews                                                0.078235
# number_of_reviews_ltm                                            0.072375
# number_of_reviews_l30d                                           0.080837
# review_scores_rating                                             0.780682
# review_scores_accuracy                                           0.604948
# review_scores_cleanliness                                        0.538849
# review_scores_checkin                                            0.585550
# review_scores_communication                                      1.000000
# review_scores_location                                           0.433315
# review_scores_value                                              0.573345
# calculated_host_listings_count                                  -0.134755
# calculated_host_listings_count_entire_homes                     -0.112799
# calculated_host_listings_count_private_rooms                    -0.058306
# calculated_host_listings_count_shared_rooms                     -0.082887
# reviews_per_month                                                0.029077
# n_bathrooms                                                           NaN
#
#                                               review_scores_location  \
# id                                                         -0.013089
# scrape_id                                                        NaN
# host_id                                                    -0.034447
# host_listings_count                                        -0.027203
# host_total_listings_count                                  -0.027203
# neighbourhood_group_cleansed                                     NaN
# latitude                                                   -0.007334
# longitude                                                  -0.083962
# accommodates                                               -0.050368
# bathrooms                                                        NaN
# bedrooms                                                   -0.039638
# beds                                                       -0.047794
# price                                                      -0.012777
# minimum_nights                                             -0.000731
# maximum_nights                                             -0.008461
# minimum_minimum_nights                                      0.001593
# maximum_minimum_nights                                     -0.012074
# minimum_maximum_nights                                     -0.007494
# maximum_maximum_nights                                     -0.008800
# minimum_nights_avg_ntm                                     -0.010024
# maximum_nights_avg_ntm                                     -0.005979
# calendar_updated                                                 NaN
# availability_30                                            -0.062187
# availability_60                                            -0.065708
# availability_90                                            -0.057543
# availability_365                                           -0.056502
# number_of_reviews                                           0.027919
# number_of_reviews_ltm                                       0.046358
# number_of_reviews_l30d                                      0.052393
# review_scores_rating                                        0.558751
# review_scores_accuracy                                      0.552212
# review_scores_cleanliness                                   0.480940
# review_scores_checkin                                       0.465646
# review_scores_communication                                 0.433315
# review_scores_location                                      1.000000
# review_scores_value                                         0.558083
# calculated_host_listings_count                              0.010222
# calculated_host_listings_count_entire_homes                 0.026662
# calculated_host_listings_count_private_rooms               -0.027964
# calculated_host_listings_count_shared_rooms                -0.115929
# reviews_per_month                                           0.016458
# n_bathrooms                                                      NaN
#
#                                               review_scores_value  \
# id                                                      -0.128419
# scrape_id                                                     NaN
# host_id                                                 -0.130533
# host_listings_count                                     -0.113838
# host_total_listings_count                               -0.113838
# neighbourhood_group_cleansed                                  NaN
# latitude                                                -0.004088
# longitude                                               -0.018999
# accommodates                                            -0.019174
# bathrooms                                                     NaN
# bedrooms                                                -0.015966
# beds                                                    -0.040697
# price                                                   -0.035118
# minimum_nights                                          -0.033286
# maximum_nights                                          -0.055055
# minimum_minimum_nights                                  -0.034317
# maximum_minimum_nights                                  -0.071580
# minimum_maximum_nights                                   0.018036
# maximum_maximum_nights                                  -0.017712
# minimum_nights_avg_ntm                                  -0.069834
# maximum_nights_avg_ntm                                  -0.006151
# calendar_updated                                              NaN
# availability_30                                         -0.182711
# availability_60                                         -0.192483
# availability_90                                         -0.184920
# availability_365                                        -0.144421
# number_of_reviews                                        0.136120
# number_of_reviews_ltm                                    0.114718
# number_of_reviews_l30d                                   0.113152
# review_scores_rating                                     0.748458
# review_scores_accuracy                                   0.680624
# review_scores_cleanliness                                0.647553
# review_scores_checkin                                    0.489377
# review_scores_communication                              0.573345
# review_scores_location                                   0.558083
# review_scores_value                                      1.000000
# calculated_host_listings_count                          -0.206654
# calculated_host_listings_count_entire_homes             -0.198286
# calculated_host_listings_count_private_rooms            -0.026510
# calculated_host_listings_count_shared_rooms             -0.081194
# reviews_per_month                                        0.053298
# n_bathrooms                                                   NaN
#
#                                               calculated_host_listings_count  \
# id                                                                  0.220619
# scrape_id                                                                NaN
# host_id                                                             0.329966
# host_listings_count                                                 0.527686
# host_total_listings_count                                           0.527686
# neighbourhood_group_cleansed                                             NaN
# latitude                                                           -0.015141
# longitude                                                          -0.040251
# accommodates                                                       -0.085145
# bathrooms                                                                NaN
# bedrooms                                                           -0.088977
# beds                                                               -0.076871
# price                                                               0.010541
# minimum_nights                                                      0.065975
# maximum_nights                                                     -0.008070
# minimum_minimum_nights                                              0.066873
# maximum_minimum_nights                                              0.219775
# minimum_maximum_nights                                             -0.171854
# maximum_maximum_nights                                             -0.138795
# minimum_nights_avg_ntm                                              0.218316
# maximum_nights_avg_ntm                                             -0.151731
# calendar_updated                                                         NaN
# availability_30                                                     0.274985
# availability_60                                                     0.263279
# availability_90                                                     0.239519
# availability_365                                                    0.250725
# number_of_reviews                                                  -0.176575
# number_of_reviews_ltm                                              -0.148818
# number_of_reviews_l30d                                             -0.110678
# review_scores_rating                                               -0.083897
# review_scores_accuracy                                             -0.084899
# review_scores_cleanliness                                          -0.059887
# review_scores_checkin                                              -0.076798
# review_scores_communication                                        -0.134755
# review_scores_location                                              0.010222
# review_scores_value                                                -0.206654
# calculated_host_listings_count                                      1.000000
# calculated_host_listings_count_entire_homes                         0.973720
# calculated_host_listings_count_private_rooms                        0.133602
# calculated_host_listings_count_shared_rooms                        -0.012539
# reviews_per_month                                                  -0.073765
# n_bathrooms                                                              NaN
#
#                                               calculated_host_listings_count_entire_homes  \
# id                                                                               0.205071
# scrape_id                                                                             NaN
# host_id                                                                          0.288948
# host_listings_count                                                              0.532582
# host_total_listings_count                                                        0.532582
# neighbourhood_group_cleansed                                                          NaN
# latitude                                                                        -0.019821
# longitude                                                                       -0.064962
# accommodates                                                                    -0.055678
# bathrooms                                                                             NaN
# bedrooms                                                                        -0.060313
# beds                                                                            -0.066177
# price                                                                            0.019913
# minimum_nights                                                                   0.076705
# maximum_nights                                                                   0.009045
# minimum_minimum_nights                                                           0.078244
# maximum_minimum_nights                                                           0.230726
# minimum_maximum_nights                                                          -0.170142
# maximum_maximum_nights                                                          -0.134004
# minimum_nights_avg_ntm                                                           0.229198
# maximum_nights_avg_ntm                                                          -0.147851
# calendar_updated                                                                      NaN
# availability_30                                                                  0.247374
# availability_60                                                                  0.230399
# availability_90                                                                  0.208172
# availability_365                                                                 0.211119
# number_of_reviews                                                               -0.167232
# number_of_reviews_ltm                                                           -0.155284
# number_of_reviews_l30d                                                          -0.128438
# review_scores_rating                                                            -0.063319
# review_scores_accuracy                                                          -0.057469
# review_scores_cleanliness                                                       -0.024862
# review_scores_checkin                                                           -0.063549
# review_scores_communication                                                     -0.112799
# review_scores_location                                                           0.026662
# review_scores_value                                                             -0.198286
# calculated_host_listings_count                                                   0.973720
# calculated_host_listings_count_entire_homes                                      1.000000
# calculated_host_listings_count_private_rooms                                    -0.089704
# calculated_host_listings_count_shared_rooms                                     -0.025789
# reviews_per_month                                                               -0.083799
# n_bathrooms                                                                           NaN
#
#                                               calculated_host_listings_count_private_rooms  \
# id                                                                                0.084815
# scrape_id                                                                              NaN
# host_id                                                                           0.193700
# host_listings_count                                                              -0.008726
# host_total_listings_count                                                        -0.008726
# neighbourhood_group_cleansed                                                           NaN
# latitude                                                                          0.019621
# longitude                                                                         0.109585
# accommodates                                                                     -0.131232
# bathrooms                                                                              NaN
# bedrooms                                                                         -0.115193
# beds                                                                             -0.063147
# price                                                                            -0.033419
# minimum_nights                                                                   -0.035995
# maximum_nights                                                                   -0.064133
# minimum_minimum_nights                                                           -0.038990
# maximum_minimum_nights                                                           -0.038361
# minimum_maximum_nights                                                            0.019566
# maximum_maximum_nights                                                            0.008634
# minimum_nights_avg_ntm                                                           -0.038051
# maximum_nights_avg_ntm                                                            0.012294
# calendar_updated                                                                       NaN
# availability_30                                                                   0.108043
# availability_60                                                                   0.130356
# availability_90                                                                   0.123656
# availability_365                                                                  0.156651
# number_of_reviews                                                                -0.048852
# number_of_reviews_ltm                                                             0.016301
# number_of_reviews_l30d                                                            0.068220
# review_scores_rating                                                             -0.045515
# review_scores_accuracy                                                           -0.062220
# review_scores_cleanliness                                                        -0.073005
# review_scores_checkin                                                            -0.027195
# review_scores_communication                                                      -0.058306
# review_scores_location                                                           -0.027964
# review_scores_value                                                              -0.026510
# calculated_host_listings_count                                                    0.133602
# calculated_host_listings_count_entire_homes                                      -0.089704
# calculated_host_listings_count_private_rooms                                      1.000000
# calculated_host_listings_count_shared_rooms                                       0.001099
# reviews_per_month                                                                 0.016541
# n_bathrooms                                                                            NaN
#
#                                               calculated_host_listings_count_shared_rooms  \
# id                                                                               0.016022
# scrape_id                                                                             NaN
# host_id                                                                          0.005926
# host_listings_count                                                             -0.005942
# host_total_listings_count                                                       -0.005942
# neighbourhood_group_cleansed                                                          NaN
# latitude                                                                        -0.024676
# longitude                                                                        0.054503
# accommodates                                                                    -0.073552
# bathrooms                                                                             NaN
# bedrooms                                                                        -0.049591
# beds                                                                             0.003143
# price                                                                           -0.047732
# minimum_nights                                                                  -0.028330
# maximum_nights                                                                  -0.019085
# minimum_minimum_nights                                                          -0.027783
# maximum_minimum_nights                                                          -0.017470
# minimum_maximum_nights                                                           0.009968
# maximum_maximum_nights                                                           0.006328
# minimum_nights_avg_ntm                                                          -0.017584
# maximum_nights_avg_ntm                                                           0.007442
# calendar_updated                                                                      NaN
# availability_30                                                                  0.125289
# availability_60                                                                  0.119580
# availability_90                                                                  0.103221
# availability_365                                                                 0.050087
# number_of_reviews                                                               -0.005250
# number_of_reviews_ltm                                                           -0.017303
# number_of_reviews_l30d                                                          -0.014126
# review_scores_rating                                                            -0.098769
# review_scores_accuracy                                                          -0.118689
# review_scores_cleanliness                                                       -0.161848
# review_scores_checkin                                                           -0.111490
# review_scores_communication                                                     -0.082887
# review_scores_location                                                          -0.115929
# review_scores_value                                                             -0.081194
# calculated_host_listings_count                                                  -0.012539
# calculated_host_listings_count_entire_homes                                     -0.025789
# calculated_host_listings_count_private_rooms                                     0.001099
# calculated_host_listings_count_shared_rooms                                      1.000000
# reviews_per_month                                                               -0.004647
# n_bathrooms                                                                           NaN
#
#                                               reviews_per_month  n_bathrooms
# id                                                    -0.056624          NaN
# scrape_id                                                   NaN          NaN
# host_id                                               -0.035374          NaN
# host_listings_count                                   -0.062149          NaN
# host_total_listings_count                             -0.062149          NaN
# neighbourhood_group_cleansed                                NaN          NaN
# latitude                                               0.043984          NaN
# longitude                                             -0.011035          NaN
# accommodates                                           0.042544          NaN
# bathrooms                                                   NaN          NaN
# bedrooms                                              -0.026523          NaN
# beds                                                   0.039007          NaN
# price                                                 -0.027024          NaN
# minimum_nights                                        -0.143804          NaN
# maximum_nights                                        -0.075642          NaN
# minimum_minimum_nights                                -0.143220          NaN
# maximum_minimum_nights                                -0.089120          NaN
# minimum_maximum_nights                                 0.016618          NaN
# maximum_maximum_nights                                 0.017415          NaN
# minimum_nights_avg_ntm                                -0.090637          NaN
# maximum_nights_avg_ntm                                 0.017644          NaN
# calendar_updated                                            NaN          NaN
# availability_30                                       -0.039131          NaN
# availability_60                                       -0.020910          NaN
# availability_90                                       -0.018729          NaN
# availability_365                                      -0.018194          NaN
# number_of_reviews                                      0.309759          NaN
# number_of_reviews_ltm                                  0.430572          NaN
# number_of_reviews_l30d                                 0.374517          NaN
# review_scores_rating                                   0.035757          NaN
# review_scores_accuracy                                 0.027417          NaN
# review_scores_cleanliness                              0.042472          NaN
# review_scores_checkin                                  0.025479          NaN
# review_scores_communication                            0.029077          NaN
# review_scores_location                                 0.016458          NaN
# review_scores_value                                    0.053298          NaN
# calculated_host_listings_count                        -0.073765          NaN
# calculated_host_listings_count_entire_homes           -0.083799          NaN
# calculated_host_listings_count_private_rooms           0.016541          NaN
# calculated_host_listings_count_shared_rooms           -0.004647          NaN
# reviews_per_month                                      1.000000          NaN
# n_bathrooms                                                 NaN          NaN
#
# [42 rows x 42 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3560 entries, 0 to 3696
# Data columns (total 76 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            3560 non-null   int64
#  1   listing_url                                   3560 non-null   object
#  2   scrape_id                                     3560 non-null   int64
#  3   last_scraped                                  3560 non-null   object
#  4   name                                          3560 non-null   object
#  5   description                                   3530 non-null   object
#  6   neighborhood_overview                         2720 non-null   object
#  7   picture_url                                   3560 non-null   object
#  8   host_id                                       3560 non-null   int64
#  9   host_url                                      3560 non-null   object
#  10  host_name                                     3560 non-null   object
#  11  host_since                                    3560 non-null   object
#  12  host_location                                 3552 non-null   object
#  13  host_about                                    2368 non-null   object
#  14  host_response_time                            3056 non-null   object
#  15  host_response_rate                            3056 non-null   object
#  16  host_acceptance_rate                          3203 non-null   object
#  17  host_is_superhost                             3560 non-null   object
#  18  host_thumbnail_url                            3560 non-null   object
#  19  host_picture_url                              3560 non-null   object
#  20  host_neighbourhood                            3178 non-null   object
#  21  host_listings_count                           3560 non-null   int64
#  22  host_total_listings_count                     3560 non-null   int64
#  23  host_verifications                            3560 non-null   object
#  24  host_has_profile_pic                          3560 non-null   object
#  25  host_identity_verified                        3560 non-null   object
#  26  neighbourhood                                 2720 non-null   object
#  27  neighbourhood_cleansed                        3560 non-null   object
#  28  neighbourhood_group_cleansed                  0 non-null      float64
#  29  latitude                                      3560 non-null   float64
#  30  longitude                                     3560 non-null   float64
#  31  property_type                                 3560 non-null   object
#  32  room_type                                     3560 non-null   object
#  33  accommodates                                  3560 non-null   int64
#  34  bathrooms                                     0 non-null      float64
#  35  bathrooms_text                                3560 non-null   object
#  36  bedrooms                                      3560 non-null   float64
#  37  beds                                          3560 non-null   float64
#  38  amenities                                     3560 non-null   object
#  39  price                                         3560 non-null   float64
#  40  minimum_nights                                3560 non-null   int64
#  41  maximum_nights                                3560 non-null   int64
#  42  minimum_minimum_nights                        3560 non-null   int64
#  43  maximum_minimum_nights                        3560 non-null   int64
#  44  minimum_maximum_nights                        3560 non-null   int64
#  45  maximum_maximum_nights                        3560 non-null   int64
#  46  minimum_nights_avg_ntm                        3560 non-null   float64
#  47  maximum_nights_avg_ntm                        3560 non-null   float64
#  48  calendar_updated                              0 non-null      float64
#  49  has_availability                              3560 non-null   object
#  50  availability_30                               3560 non-null   int64
#  51  availability_60                               3560 non-null   int64
#  52  availability_90                               3560 non-null   int64
#  53  availability_365                              3560 non-null   int64
#  54  calendar_last_scraped                         3560 non-null   object
#  55  number_of_reviews                             3560 non-null   int64
#  56  number_of_reviews_ltm                         3560 non-null   int64
#  57  number_of_reviews_l30d                        3560 non-null   int64
#  58  first_review                                  3027 non-null   object
#  59  last_review                                   3027 non-null   object
#  60  review_scores_rating                          3027 non-null   float64
#  61  review_scores_accuracy                        3022 non-null   float64
#  62  review_scores_cleanliness                     3022 non-null   float64
#  63  review_scores_checkin                         3022 non-null   float64
#  64  review_scores_communication                   3022 non-null   float64
#  65  review_scores_location                        3022 non-null   float64
#  66  review_scores_value                           3022 non-null   float64
#  67  license                                       2437 non-null   object
#  68  instant_bookable                              3560 non-null   object
#  69  calculated_host_listings_count                3560 non-null   int64
#  70  calculated_host_listings_count_entire_homes   3560 non-null   int64
#  71  calculated_host_listings_count_private_rooms  3560 non-null   int64
#  72  calculated_host_listings_count_shared_rooms   3560 non-null   int64
#  73  reviews_per_month                             3560 non-null   float64
#  74  n_bathrooms                                   3560 non-null   int64
#  75  shared_private                                3560 non-null   object
# dtypes: float64(18), int64(24), object(34)
# memory usage: 2.1+ MB

# %%
df2 = df.drop(columns = ["id", "listing_url", "scrape_id", "last_scraped", "name" ,"description","neighborhood_overview", "picture_url", "host_id", "host_name", "host_since", "host_location",
                        "host_url", "host_about", "host_response_rate", "host_thumbnail_url", "host_picture_url", "host_listings_count", "host_verifications", "host_identity_verified", "host_neighbourhood",
                        "neighbourhood","neighbourhood_group_cleansed", "latitude", "longitude", "bathrooms", "license", "instant_bookable", "calculated_host_listings_count",
                        "calculated_host_listings_count_entire_homes", "calculated_host_listings_count_private_rooms", "calculated_host_listings_count_shared_rooms",
                        "bathrooms_text" ,"minimum_minimum_nights", "maximum_minimum_nights", "minimum_nights_avg_ntm", "maximum_nights_avg_ntm",
                        'availability_60', 'availability_90', 'availability_365', 'review_scores_accuracy',
                       'review_scores_cleanliness', 'review_scores_checkin',
                        'review_scores_communication', 'review_scores_location',
                       'review_scores_value', 'reviews_per_month','calendar_updated', 'has_availability', 'availability_30','calendar_last_scraped','number_of_reviews_ltm'])
df2.columns
# Out:
# Index(['host_response_time', 'host_acceptance_rate', 'host_is_superhost',
#        'host_total_listings_count', 'host_has_profile_pic',
#        'neighbourhood_cleansed', 'property_type', 'room_type', 'accommodates',
#        'bedrooms', 'beds', 'amenities', 'price', 'minimum_nights',
#        'maximum_nights', 'minimum_maximum_nights', 'maximum_maximum_nights',
#        'number_of_reviews', 'number_of_reviews_l30d', 'first_review',
#        'last_review', 'review_scores_rating', 'n_bathrooms', 'shared_private'],
#       dtype='object')
